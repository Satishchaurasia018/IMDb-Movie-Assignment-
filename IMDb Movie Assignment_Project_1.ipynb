# %% [markdown]
# # IMDb Movie Assignment:
# ## About the data set:
# Dataset is for the 100 top-rated movies from the past decade along with various pieces of information about the movie, its actors, and the voters who have rated these movies online. In this assignment, you will try to find some interesting insights into these movies and their voters, using Python.

# %%
# Filtering out the warnings
import warnings

warnings.filterwarnings('ignore')

# %%
# Importing the libraries

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# import the dataset

movies = pd.read_csv(r"C:\Users\satis\Desktop\Projects\1st CaseStudy\Movie+Assignment+Data.csv")

# %%
# Read the datasets top 5 rows

movies.head()
# Out:
#                    Title  title_year     budget      Gross      actor_1_name  \
# 0             La La Land        2016   30000000  151101803      Ryan Gosling
# 1               Zootopia        2016  150000000  341268248  Ginnifer Goodwin
# 2                   Lion        2016   12000000   51738905         Dev Patel
# 3                Arrival        2016   47000000  100546139         Amy Adams
# 4  Manchester by the Sea        2016    9000000   47695371     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone       Amiée Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  ...  Votes3044M Votes3044F  \
# ...

# %%
# read the number of columns and rows in dataset

movies.shape
# Out:
# (100, 62)

# %%
#Read the column-wise info of the dataframe

movies. info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 97 to 22
# Data columns (total 65 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   100 non-null    object
#  1   title_year              100 non-null    int64
#  2   budget                  100 non-null    float64
#  3   Gross                   100 non-null    float64
#  4   actor_1_name            100 non-null    object
#  5   actor_2_name            100 non-null    object
#  6   actor_3_name            100 non-null    object
#  7   actor_1_facebook_likes  100 non-null    int64
#  8   actor_2_facebook_likes  99 non-null     float64
#  9   actor_3_facebook_likes  98 non-null     float64
#  10  IMDb_rating             100 non-null    float64
#  11  genre_1                 100 non-null    object
#  12  genre_2                 97 non-null     object
#  13  genre_3                 74 non-null     object
# ...

# %%
# Check the summary for the numeric columns 

movies.describe()
# Out:
#         title_year        budget         Gross  actor_1_facebook_likes  \
# count   100.000000  1.000000e+02  1.000000e+02              100.000000
# mean   2012.820000  7.838400e+07  1.468679e+08            13407.270000
# std       1.919491  7.445295e+07  1.454004e+08            10649.037862
# min    2010.000000  3.000000e+06  2.238380e+05               39.000000
# 25%    2011.000000  1.575000e+07  4.199752e+07             1000.000000
# 50%    2013.000000  4.225000e+07  1.070266e+08            13000.000000
# 75%    2014.000000  1.500000e+08  2.107548e+08            20000.000000
# max    2016.000000  2.600000e+08  9.366622e+08            35000.000000
#
#        actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating  \
# count               99.000000               98.000000   100.000000
# mean              7377.303030             3002.153061     7.883000
# std              13471.568216             6940.301133     0.247433
# ...

# %%
movies["Gross"]=movies["Gross"]/1000000
movies["budget"]=movies["budget"]/1000000
movies.head()
# Out:
#                    Title  title_year  budget       Gross      actor_1_name  \
# 0             La La Land        2016    30.0  151.101803      Ryan Gosling
# 1               Zootopia        2016   150.0  341.268248  Ginnifer Goodwin
# 2                   Lion        2016    12.0   51.738905         Dev Patel
# 3                Arrival        2016    47.0  100.546139         Amy Adams
# 4  Manchester by the Sea        2016     9.0   47.695371     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone       Amiée Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  ...  Votes3044M Votes3044F  \
# ...

# %% [markdown]
# # Data Analysis
# Now that we have loaded the dataset and inspected it, we see that most of the data is in place. As of now, no data cleaning is required, so let's start with some data manipulation, analysis, and visualisation to get various insights about the data.
#
# ## Reduce those Digits!
# These numbers in the budget and gross are too big, compromising its readability. Let's convert the unit of the budget and gross columns from $ to million $ first.

# %%
movies["Profit"] = movies["Gross"]-movies["budget"]
movies.head()
# Out:
#                    Title  title_year  budget       Gross      actor_1_name  \
# 0             La La Land        2016    30.0  151.101803      Ryan Gosling
# 1               Zootopia        2016   150.0  341.268248  Ginnifer Goodwin
# 2                   Lion        2016    12.0   51.738905         Dev Patel
# 3                Arrival        2016    47.0  100.546139         Amy Adams
# 4  Manchester by the Sea        2016     9.0   47.695371     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone       Amiée Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  ...  Votes3044F Votes45A  \
# ...

# %%
# sort the dataframe with the profit cloumn as referance useing the 'sort_values' funcation

movies = movies.sort_values(by = "Profit", ascending = False)
movies
# Out:
#                                          Title  title_year  budget  \
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0
# 11                                The Avengers        2012   220.0
# 47                                    Deadpool        2016    58.0
# 32             The Hunger Games: Catching Fire        2013   130.0
# 12                                 Toy Story 3        2010   200.0
# ..                                         ...         ...     ...
# 46                 Scott Pilgrim vs. the World        2010    60.0
# 7                                      Tangled        2010   260.0
# 17                            Edge of Tomorrow        2014   178.0
# 39                           The Little Prince        2015    81.2
# 22                                        Hugo        2011   170.0
#
#          Gross         actor_1_name       actor_2_name           actor_3_name  \
# 97  936.662225          Doug Walker         Rob Walker                      0
# ...

# %%
# Get the top 10 profitable movies by using position bassed indexing.

movies.iloc[:10,:]
# Out:
#                                          Title  title_year  budget  \
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0
# 11                                The Avengers        2012   220.0
# 47                                    Deadpool        2016    58.0
# 32             The Hunger Games: Catching Fire        2013   130.0
# 12                                 Toy Story 3        2010   200.0
# 8                        The Dark Knight Rises        2012   250.0
# 45                              The Lego Movie        2014    60.0
# 1                                     Zootopia        2016   150.0
# 41                               Despicable Me        2010    69.0
# 18                                  Inside Out        2015   175.0
#
#          Gross       actor_1_name       actor_2_name           actor_3_name  \
# 97  936.662225        Doug Walker         Rob Walker                      0
# ...

# %%
# Plot profit vs budget

sns.jointplot('budget','Profit',movies)
plt.show()

# %%
# find the movies with nigative profit

movies[movies["Profit"]<0]
# Out:
#                           Title  title_year  budget       Gross  \
# 99      Tucker and Dale vs Evil        2010     5.0    0.223838
# 89                        Amour        2012     8.9    0.225377
# 56                         Rush        2013    38.0   26.903709
# 66                      Warrior        2011    25.0   13.651662
# 82                      Flipped        2010    14.0    1.752214
# 28           X-Men: First Class        2011   160.0  146.405371
# 46  Scott Pilgrim vs. the World        2010    60.0   31.494270
# 7                       Tangled        2010   260.0  200.807262
# 17             Edge of Tomorrow        2014   178.0  100.189501
# 39            The Little Prince        2015    81.2    1.339152
# 22                         Hugo        2011   170.0   73.820094
#
#            actor_1_name        actor_2_name            actor_3_name  \
# 99       Katrina Bowden        Tyler Labine          Chelan Simmons
# ...

# %%
movies.columns
# Out:
# Index(['Title', 'title_year', 'budget', 'Gross', 'actor_1_name',
#        'actor_2_name', 'actor_3_name', 'actor_1_facebook_likes',
#        'actor_2_facebook_likes', 'actor_3_facebook_likes', 'IMDb_rating',
#        'genre_1', 'genre_2', 'genre_3', 'MetaCritic', 'Runtime', 'CVotes10',
#        'CVotes09', 'CVotes08', 'CVotes07', 'CVotes06', 'CVotes05', 'CVotes04',
#        'CVotes03', 'CVotes02', 'CVotes01', 'CVotesMale', 'CVotesFemale',
#        'CVotesU18', 'CVotesU18M', 'CVotesU18F', 'CVotes1829', 'CVotes1829M',
#        'CVotes1829F', 'CVotes3044', 'CVotes3044M', 'CVotes3044F', 'CVotes45A',
#        'CVotes45AM', 'CVotes45AF', 'CVotes1000', 'CVotesUS', 'CVotesnUS',
#        'VotesM', 'VotesF', 'VotesU18', 'VotesU18M', 'VotesU18F', 'Votes1829',
#        'Votes1829M', 'Votes1829F', 'Votes3044', 'Votes3044M', 'Votes3044F',
#        'Votes45A', 'Votes45AM', 'Votes45AF', 'Votes1000', 'VotesUS',
#        'VotesnUS', 'content_rating', 'Country', 'Profit'],
#       dtype='object')

# %%
# Change the scale of MetaCritic column

movies['MetaCritic']=movies['MetaCritic']/10

# %%
# Find the average ratings
movies['Ave_rating']=(movies['IMDb_rating']+movies['MetaCritic'])/2
movies.head()
# Out:
#                                          Title  title_year  budget  \
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0
# 11                                The Avengers        2012   220.0
# 47                                    Deadpool        2016    58.0
# 32             The Hunger Games: Catching Fire        2013   130.0
# 12                                 Toy Story 3        2010   200.0
#
#          Gross       actor_1_name       actor_2_name           actor_3_name  \
# 97  936.662225        Doug Walker         Rob Walker                      0
# 11  623.279547    Chris Hemsworth  Robert Downey Jr.     Scarlett Johansson
# 47  363.024263      Ryan Reynolds          Ed Skrein         Stefan Kapicic
# 32  424.645577  Jennifer Lawrence    Josh Hutcherson  Sandra Ellis Lafferty
# 12  414.984497          Tom Hanks  John Ratzenberger            Don Rickles
#
#     actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# ...

# %%
#Sort in descending order of average rating

df = movies[['Title','IMDb_rating','MetaCritic','Ave_rating']]
df = df.loc[abs(df['IMDb_rating']-df['MetaCritic']<0.5)]

# %%
# Find the movies with metacritic-IMDb_rating < 0.5 and also with the average rating of >8
df = df.sort_values(by = "Ave_rating", ascending = False)
UniversalAcclaim = df.loc[df['Ave_rating']>=8]
UniversalAcclaim
# Out:
#                                               Title  IMDb_rating  MetaCritic  \
# 94                                          Boyhood          7.9        10.0
# 69                                 12 Years a Slave          8.1         9.6
# 18                                       Inside Out          8.2         9.4
# 12                                      Toy Story 3          8.3         9.2
# 0                                        La La Land          8.2         9.3
# 4                             Manchester by the Sea          7.9         9.6
# 70                                        Spotlight          8.1         9.3
# 34                                          Gravity          7.8         9.6
# 96                                  Before Midnight          7.9         9.4
# 89                                            Amour          7.9         9.4
# 95                                         Whiplash          8.5         8.8
# ...

# %%
group = movies.pivot_table(values=['actor_1_facebook_likes', 'actor_2_facebook_likes','actor_3_facebook_likes'],
                  aggfunc='sum',index = ['actor_1_name','actor_2_name','actor_3_name'])

# %%
# Create a new column named total likes

group['Total_Likes']= group['actor_1_facebook_likes']+group['actor_2_facebook_likes']+group['actor_3_facebook_likes']
group
# Out:
#                                                     actor_1_facebook_likes  \
# actor_1_name  actor_2_name    actor_3_name
# Aidan Turner  Adam Brown      James Nesbitt                          10000
# Albert Finney Helen McCrory   Rory Kinnear                             883
# Aldis Hodge   Neil Brown Jr.  R. Marcos Taylor                         559
# Amy Adams     Jeremy Renner   Forest Whitaker                        35000
# Amy Poehler   Mindy Kaling    Phyllis Smith                           1000
# ...                                                                    ...
# Tom Hanks     Mark Rylance    Amy Ryan                               15000
# Tom Hardy     Charlize Theron ZoÃ« Kravitz                           27000
#               Christian Bale  Joseph Gordon-Levitt                   27000
#               Frank Grillo    Kevin Dunn                             27000
# Tom Hughes    Tom Hollander   Lindsay Duncan                           565
#
# ...

# %%
group.sort_values(by='Total_Likes', ascending = False, inplace = True)
group
# Out:
#                                                                     actor_1_facebook_likes  \
# actor_1_name             actor_2_name       actor_3_name
# Dev Patel                Nicole Kidman      Rooney Mara                              33000
# Leonardo DiCaprio        Tom Hardy          Joseph Gordon-Levitt                     29000
# Jennifer Lawrence        Peter Dinklage     Hugh Jackman                             34000
# Casey Affleck            Michelle Williams  Kyle Chandler                              518
# Tom Hardy                Christian Bale     Joseph Gordon-Levitt                     27000
# ...                                                                                    ...
# Ellar Coltrane           Lorelei Linklater  Libby Villari                              230
# Elina Alminas            Sonoya Mizuno      Corey Johnson                              149
# Seamus Davey-Fitzpatrick Ariane Labed       Athina Rachel Tsangari                     140
# ...

# %%
group.reset_index(inplace = True)
group
# Out:
#                 actor_1_name        actor_2_name            actor_3_name  \
# 0                  Dev Patel       Nicole Kidman             Rooney Mara
# 1          Leonardo DiCaprio           Tom Hardy    Joseph Gordon-Levitt
# 2          Jennifer Lawrence      Peter Dinklage            Hugh Jackman
# 3              Casey Affleck  Michelle Williams            Kyle Chandler
# 4                  Tom Hardy      Christian Bale    Joseph Gordon-Levitt
# ..                       ...                 ...                     ...
# 94            Ellar Coltrane   Lorelei Linklater           Libby Villari
# 95             Elina Alminas       Sonoya Mizuno           Corey Johnson
# 96  Seamus Davey-Fitzpatrick        Ariane Labed  Athina Rachel Tsangari
# 97               Doug Walker          Rob Walker                       0
# 98            Phaldut Sharma       Basher Savage              Amy Warren
#
#     actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# ...

# %%
group.head()
# Out:
#         actor_1_name        actor_2_name          actor_3_name  \
# 0          Dev Patel       Nicole Kidman           Rooney Mara
# 1  Leonardo DiCaprio           Tom Hardy  Joseph Gordon-Levitt
# 2  Jennifer Lawrence      Peter Dinklage          Hugh Jackman
# 3      Casey Affleck  Michelle Williams          Kyle Chandler
# 4          Tom Hardy      Christian Bale  Joseph Gordon-Levitt
#
#    actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 0                   33000                 96000.0                  9800.0
# 1                   29000                 27000.0                 23000.0
# 2                   34000                 22000.0                 20000.0
# 3                     518                 71000.0                  3300.0
# 4                   27000                 23000.0                 23000.0
#
#    Total_Likes
# 0     138800.0
# 1      79000.0
# 2      76000.0
# 3      74818.0
# 4      73000.0

# %%
group=group.iloc[0:5,:]
group
# Out:
#         actor_1_name        actor_2_name          actor_3_name  \
# 0          Dev Patel       Nicole Kidman           Rooney Mara
# 1  Leonardo DiCaprio           Tom Hardy  Joseph Gordon-Levitt
# 2  Jennifer Lawrence      Peter Dinklage          Hugh Jackman
# 3      Casey Affleck  Michelle Williams          Kyle Chandler
# 4          Tom Hardy      Christian Bale  Joseph Gordon-Levitt
#
#    actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 0                   33000                 96000.0                  9800.0
# 1                   29000                 27000.0                 23000.0
# 2                   34000                 22000.0                 20000.0
# 3                     518                 71000.0                  3300.0
# 4                   27000                 23000.0                 23000.0
#
#    Total_Likes
# 0     138800.0
# 1      79000.0
# 2      76000.0
# 3      74818.0
# 4      73000.0

# %%
sorted([1,5,2])
# Out:
# [1, 2, 5]

# %%
j=0
for i in group['Total_Likes']:
    temp=sorted([group.loc[j,"actor_1_facebook_likes"],group.loc[j,"actor_2_facebook_likes"],group.loc[j,"actor_3_facebook_likes"]])
    if temp[0]>=temp[1]/2 and temp[0]>=temp[2]/2 and temp[1]>=temp[2]/2:
        print(sorted([group.loc[j,"actor_1_name"],group.loc[j,"actor_2_name"],group.loc[j,"actor_3_name"]]))
    j=j+1
# Out:
# ['Joseph Gordon-Levitt', 'Leonardo DiCaprio', 'Tom Hardy']
# ['Hugh Jackman', 'Jennifer Lawrence', 'Peter Dinklage']
# ['Christian Bale', 'Joseph Gordon-Levitt', 'Tom Hardy']

# %%
# Create Histogram plot

plt.hist(movies["Runtime"])
plt.show()

# %%
#R-Rated Movies

movies.loc[movies["content_rating"]== "R"].sort_values(by='CVotesU18',ascending = False)[['Title','CVotesU18']].head(10)
# Out:
#                                               Title  CVotesU18
# 47                                         Deadpool       4598
# 36                          The Wolf of Wall Street       3622
# 35                                 Django Unchained       3250
# 29                               Mad Max: Fury Road       3159
# 95                                         Whiplash       2878
# 31                                     The Revenant       2619
# 40                                   Shutter Island       2321
# 43                                        Gone Girl       2286
# 65                         The Grand Budapest Hotel       2083
# 72  Birdman or (The Unexpected Virtue of Ignorance)       1891

# %%
# Create the dataframe df_by_genre
df_by_genre=movies.loc[:,"CVotes10":"VotesnUS"]
df_by_genre[['genre_1', 'genre_2', 'genre_3']]=movies[['genre_1', 'genre_2', 'genre_3']]

# %%
df_by_genre
# Out:
#     CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  CVotes04  \
# 97    155391    161810    166378     99402     40734     18060      8751
# 11    260257    234203    264290    162604     67579     27957     12176
# 47    147467    147966    170810    105717     41811     15510      7046
# 32     85219     83874    150153    121748     50575     18571      7591
# 12    139773    149992    158704     88289     31291     11850      4859
# ..       ...       ...       ...       ...       ...       ...       ...
# 46     47292     48976     79198     59689     28452     13451      6977
# 7      56575     54688     97207     70947     26805      8530      3043
# 17     60383     99596    175961    100724     28982      8145      2858
# 39      7565      7321     11668      8558      3370      1162       456
# 22     29228     40728     77893     62936     27932     11179      4664
#
#     CVotes03  CVotes02  CVotes01  ...  Votes3044F  Votes45A  Votes45AM  \
# ...

# %%
# Create a column cnt and initialize it to 1

df_by_genre['Cnt']=1

# %%
df_by_genre[['genre_1', 'genre_2', 'genre_3']]
# Out:
#       genre_1    genre_2  genre_3
# 97     Action  Adventure  Fantasy
# 11     Action     Sci-Fi      NaN
# 47     Action  Adventure   Comedy
# 32     Action  Adventure  Mystery
# 12  Animation  Adventure   Comedy
# ..        ...        ...      ...
# 46     Action     Comedy  Romance
# 7   Animation  Adventure   Comedy
# 17     Action  Adventure   Sci-Fi
# 39  Animation  Adventure    Drama
# 22  Adventure      Drama   Family
#
# [100 rows x 3 columns]

# %%
# Group the movies by individual genres
df_by_g1=df_by_genre.groupby('genre_1').aggregate(np.sum)
df_by_g2=df_by_genre.groupby('genre_2').aggregate(np.sum)
df_by_g3=df_by_genre.groupby('genre_3').aggregate(np.sum)

# %%
df_by_g1
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_1
# Action      2928407   3261919   4247693   2662020    986774    364234
# Adventure   1058779   1179818   1560541    966275    365486    136985
# Animation    681562    798227   1153214    722782    251076     83069
# Biography    666831   1088430   1654704    962977    306247    100005
# Comedy       371217    496905    770395    518566    205434     81933
# Crime        383290    690221   1083469    627593    206756     71460
# Drama       1080725   1494053   1827363   1078966    417205    163874
# Mystery      150405    230844    278844    132349     45167     15615
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes3044  Votes3044M  \
# genre_1                                            ...
# Action       156150     89483     61975    162426  ...      209.1       208.8
# Adventure     58559     33174     22018     48100  ...       92.7        92.6
# ...

# %%
df_by_g2
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_2
# Action       238060    285510    430062    260106     88580     29250
# Adventure   2297820   2548864   3271725   2055600    758009    272735
# Biography    185172    313178    576374    370003    119348     38643
# Comedy       428995    624720    854162    512668    193916     76752
# Crime         19576     40247     85359     64633     24920      8548
# Drama       1923492   2761237   4112363   2492241    853434    300100
# Family        68937     54947    102488     80465     31205     11792
# Fantasy      270616    290831    447307    291071    120920     47215
# History       15757     32840     83322     63800     19183      5178
# Horror        16572     19818     44460     35863     13456      4588
# Music        110404    161864    132656     56007     16577      6031
# Musical       54268     47750     63323     45160     22393     10744
# ...

# %%
# Add the grouped data frames and store it in a new data frame
df_add=df_by_g1.add(df_by_g2,fill_value=0)
df_add=df_add.add(df_by_g3,fill_value=0)
df_add
# Out:
#             CVotes10   CVotes09   CVotes08   CVotes07   CVotes06  CVotes05  \
# Action     3166467.0  3547429.0  4677755.0  2922126.0  1075354.0  393484.0
# Adventure  3594659.0  4014192.0  5262328.0  3281981.0  1212075.0  438970.0
# Animation   681562.0   798227.0  1153214.0   722782.0   251076.0   83069.0
# Biography   852003.0  1401608.0  2231078.0  1332980.0   425595.0  138648.0
# Comedy     1383616.0  1774987.0  2506851.0  1591069.0   600287.0  226852.0
# Crime       574526.0   967118.0  1419495.0   821390.0   278391.0   98690.0
# Drama      3404438.0  4935375.0  7107053.0  4319700.0  1529356.0  552312.0
# Family       98165.0    95675.0   180381.0   143401.0    59137.0   22971.0
# Fantasy     572452.0   602223.0   889767.0   599747.0   241831.0   93484.0
# History     151261.0   260387.0   394531.0   223062.0    67861.0   21233.0
# Horror       16572.0    19818.0    44460.0    35863.0    13456.0    4588.0
# ...

# %%
# Extract genres with atleast 10 occurences
genre_top_10=df_add.loc[df_add["Cnt"]>10]

# %%
genre_top_10
# Out:
#             CVotes10   CVotes09   CVotes08   CVotes07   CVotes06  CVotes05  \
# Action     3166467.0  3547429.0  4677755.0  2922126.0  1075354.0  393484.0
# Adventure  3594659.0  4014192.0  5262328.0  3281981.0  1212075.0  438970.0
# Animation   681562.0   798227.0  1153214.0   722782.0   251076.0   83069.0
# Biography   852003.0  1401608.0  2231078.0  1332980.0   425595.0  138648.0
# Comedy     1383616.0  1774987.0  2506851.0  1591069.0   600287.0  226852.0
# Crime       574526.0   967118.0  1419495.0   821390.0   278391.0   98690.0
# Drama      3404438.0  4935375.0  7107053.0  4319700.0  1529356.0  552312.0
# Romance     549959.0   689492.0  1069280.0   712841.0   281289.0  110901.0
# Sci-Fi     2325284.0  2530855.0  3002994.0  1802098.0   671811.0  254175.0
# Thriller   1081701.0  1465491.0  1993378.0  1175799.0   416046.0  149953.0
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes3044  Votes3044M  \
# ...

# %%
# Take the mean for every column by dividing with cnt 

genre_top_10.iloc[:,0:-1]=genre_top_10.iloc[:,0:-1].divide(genre_top_10["Cnt"],axis=0)

# %%
genre_top_10
# Out:
#                 CVotes10       CVotes09       CVotes08       CVotes07  \
# Action     102144.096774  114433.193548  150895.322581   94262.129032
# Adventure   94596.289474  105636.631579  138482.315789   86367.921053
# Animation   61960.181818   72566.090909  104837.636364   65707.454545
# Biography   47333.500000   77867.111111  123948.777778   74054.444444
# Comedy      60157.217391   77173.347826  108993.521739   69176.913043
# Crime       52229.636364   87919.818182  129045.000000   74671.818182
# Drama       52375.969231   75928.846154  109339.276923   66456.923077
# Romance     42304.538462   53037.846154   82252.307692   54833.923077
# Sci-Fi     136781.411765  148873.823529  176646.705882  106005.764706
# Thriller    83207.769231  112730.076923  153336.769231   90446.076923
#
#                CVotes06      CVotes05     CVotes04     CVotes03     CVotes02  \
# Action     34688.838710  12693.032258  5386.129032  3064.645161  2115.258065
# ...

# %%
# Rounding off the columns of Votes to two decimals

genre_top_10.loc[:,"VotesM":"VotesnUS"]=round(genre_top_10.loc[:,"VotesM":"VotesnUS"],2)

# %%
# Converting CVotes to int type
genre_top_10[genre_top_10.loc[:,"CVotes10":"CVotesnUS"].columns]=genre_top_10[genre_top_10.loc[:,"CVotes10":"CVotesnUS"].columns].astype(int)
genre_top_10
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# Action       102144    114433    150895     94262     34688     12693
# Adventure     94596    105636    138482     86367     31896     11551
# Animation     61960     72566    104837     65707     22825      7551
# Biography     47333     77867    123948     74054     23644      7702
# Comedy        60157     77173    108993     69176     26099      9863
# Crime         52229     87919    129045     74671     25308      8971
# Drama         52375     75928    109339     66456     23528      8497
# Romance       42304     53037     82252     54833     21637      8530
# Sci-Fi       136781    148873    176646    106005     39518     14951
# Thriller      83207    112730    153336     90446     32003     11534
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes3044  Votes3044M  \
# Action         5386      3064      2115      5524  ...       7.74        7.73
# ...

# %% [markdown]
# # Genre Counts!
# Now let's derive some insights from this data frame. Make a bar chart plotting different genres vs cnt using seaborn.

# %%
# Countplot for genres
sns.barplot(x = genre_top_10['Cnt'],y = genre_top_10.index)
plt.show()

# %%
# 1st set of heat maps for CVotes-related columns

plt.figure(figsize = (18,8))
plt.subplot(1,2,1)
ax = sns.heatmap(genre_top_10[["CVotesU18M","CVotes1829M","CVotes3044M","CVotes45AM"]], annot = True,cmap = 'coolwarm')
plt.subplot(1,2,2)

ax = sns.heatmap(genre_top_10[["CVotesU18F","CVotes1829F","CVotes3044F","CVotes45AF"]], annot = True,cmap = 'coolwarm')

plt.show()

# %% [markdown]
# Inference 1: Genre romance has got the least number of votes among any age group of males, but there is no such pattern among the females
#
# Inference 2: Action seems to be the more popular genre among the under 18 males, and Animation appears to be the most popular genre among under 18 females.
#
# Inference 3: 18-29 age group seems to be most actively voting for any genre irrespective of gender

# %%
# 2nd set of heat maps for Votes-related columns

plt.figure(figsize = (20,10))
plt.subplot(1,2,1)
ax = sns.heatmap(genre_top_10[["VotesU18M","Votes1829M","Votes3044M","Votes45AM"]], annot = True,cmap = 'coolwarm')
plt.subplot(1,2,2)

ax = sns.heatmap(genre_top_10[["VotesU18F","Votes1829F","Votes3044F","Votes45AF"]], annot = True,cmap = 'coolwarm')

plt.show()

# %% [markdown]
# Inference 1: The rating among the males seems to be decreasing with increasing age group. There is similar pattern among female but with few exeptions
# Inference 2: Crime genre has the second highst rating among U18 age group of both males and males but among U10 Female, it has got the least rating
# Inference 3: Romance genre has got the least rating among both 45 above male and female

# %% [markdown]
# # US vs non-US Cross Analysis
# The dataset contains both the US and non-US movies. Let's analyse how both the US and the non-US voters have responded to the US and the non-US movies.

# %%
movies['Country'].value_counts()
# Out:
# USA          81
# UK           11
# Australia     3
# France        3
# Spain         1
# Canada        1
# Name: Country, dtype: int64

# %%
# Creating IFUS column
movies['IFUS']=movies['Country'].copy()

# %%
movies.loc[movies["IFUS"]!="USA","IFUS"]="non-USA"

# %%
movies['IFUS'].value_counts()
# Out:
# USA        81
# non-USA    19
# Name: IFUS, dtype: int64

# %%
# Box plot - 1: CVotesUS(y) vs IFUS(x)

plt.figure(figsize= (15,10))
plt.subplot(1,2,1)
sns.boxplot(x='IFUS',y='CVotesUS',data=movies)
plt.subplot(1,2,2)
sns.boxplot(x='IFUS',y='CVotesnUS',data=movies)
# Out:
# <AxesSubplot:xlabel='IFUS', ylabel='CVotesnUS'>

# %% [markdown]
# Inference 1: US movies have got a high number of votes from both US and non-US voters when we compare medians of the box plot
#
# Inference 2: Non-US moves have a more uniform distribution of the number of votes as compare to the USA movies which is evident from the values of the quartiles

# %% [markdown]
# # Top 1000 Voters Vs Genres

# %%
# Sorting by CVotes1000
genre_top_10=genre_top_10.sort_values('CVotes1000',ascending = False)
genre_top_10
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# Sci-Fi       136781    148873    176646    106005     39518     14951
# Action       102144    114433    150895     94262     34688     12693
# Thriller      83207    112730    153336     90446     32003     11534
# Adventure     94596    105636    138482     86367     31896     11551
# Crime         52229     87919    129045     74671     25308      8971
# Comedy        60157     77173    108993     69176     26099      9863
# Biography     47333     77867    123948     74054     23644      7702
# Drama         52375     75928    109339     66456     23528      8497
# Animation     61960     72566    104837     65707     22825      7551
# Romance       42304     53037     82252     54833     21637      8530
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes3044  Votes3044M  \
# Sci-Fi         6583      3876      2715      6731  ...       7.86        7.85
# ...

# %%
genre_top_10['CVotes1000']
# Out:
# Sci-Fi       714
# Action       681
# Thriller     669
# Adventure    662
# Crime        620
# Comedy       605
# Biography    600
# Drama        585
# Animation    578
# Romance      548
# Name: CVotes1000, dtype: int32

# %%
# Bar Plot
plt.figure(figsize = (15,5))
sns.barplot(genre_top_10.index,genre_top_10['CVotes1000'])
plt.show()

# %% [markdown]
# # Thank You!!
